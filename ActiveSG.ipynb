# %% [markdown]
# ActiveSG

# %%
# Data processing
import numpy as np
import pandas as pd
import geopandas as gpd

# Visualisation
import matplotlib
from ipyleaflet import Map, GeoData, basemaps, LayersControl
import seaborn
import folium
import mapclassify

# %%
activesg = gpd.read_file('Data Sources/1_data/ActiveSG-Sports/sportsg-sport-facilities-geojson.geojson')
activesg.to_file('Generated Files/activesg.shp')
activesg
# Out:
# /var/folders/fv/tvh892ks5mz1ls6_l14p3kzm0000gn/T/ipykernel_78887/1049501910.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   activesg.to_file('Generated Files/activesg.shp')
#       Name                                        Description  \
# 0    kml_1  <center><table><tr><th colspan='2' align='cent...
# 1    kml_2  <center><table><tr><th colspan='2' align='cent...
# 2    kml_3  <center><table><tr><th colspan='2' align='cent...
# 3    kml_4  <center><table><tr><th colspan='2' align='cent...
# 4    kml_5  <center><table><tr><th colspan='2' align='cent...
# 5    kml_6  <center><table><tr><th colspan='2' align='cent...
# 6    kml_7  <center><table><tr><th colspan='2' align='cent...
# 7    kml_8  <center><table><tr><th colspan='2' align='cent...
# 8    kml_9  <center><table><tr><th colspan='2' align='cent...
# 9   kml_10  <center><table><tr><th colspan='2' align='cent...
# ...
