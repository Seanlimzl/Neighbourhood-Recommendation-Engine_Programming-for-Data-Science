# %%
# Data processing
import numpy as np
import pandas as pd
import geopandas as gpd

# Visualisation
import matplotlib
from ipyleaflet import Map, GeoData, basemaps, LayersControl
import seaborn
import folium
import mapclassify

# %%
schools = pd.read_csv('Data Sources/Teyang_Lau_data/school_coordinates.csv')
schools.head()
# Out:
#    Unnamed: 0                                            ADDRESS BLK_NO  \
# 0           0  30 BUKIT BATOK WEST AVENUE 3 PRINCESS ELIZABET...     30
# 1           0  2 WOODLANDS DRIVE 14 WOODGROVE PRIMARY SCHOOL ...      2
# 2           0  51 CORONATION ROAD NANYANG PRIMARY SCHOOL SING...     51
# 3           1  52 KING'S ROAD NANYANG PRIMARY SCHOOL SINGAPOR...     52
# 4           0  70 PUNGGOL DRIVE WATERWAY PRIMARY SCHOOL SINGA...     70
#
#                             BUILDING  LATITUDE   LONGITUDE  LONGTITUDE  \
# 0  PRINCESS ELIZABETH PRIMARY SCHOOL  1.349195  103.741000  103.741000
# 1           WOODGROVE PRIMARY SCHOOL  1.433058  103.790390  103.790390
# 2             NANYANG PRIMARY SCHOOL  1.321115  103.806468  103.806468
# 3             NANYANG PRIMARY SCHOOL  1.321246  103.807795  103.807795
# 4            WATERWAY PRIMARY SCHOOL  1.399154  103.918671  103.918671
#
#    POSTAL                  ROAD_NAME                          SEARCHVAL  \
# ...

# %%
schools_gdf = gpd.GeoDataFrame(
    schools, geometry=gpd.points_from_xy(schools.X, schools.Y), crs='EPSG:3414'
)
schools_gdf.head()
# Out:
#    Unnamed: 0                                            ADDRESS BLK_NO  \
# 0           0  30 BUKIT BATOK WEST AVENUE 3 PRINCESS ELIZABET...     30
# 1           0  2 WOODLANDS DRIVE 14 WOODGROVE PRIMARY SCHOOL ...      2
# 2           0  51 CORONATION ROAD NANYANG PRIMARY SCHOOL SING...     51
# 3           1  52 KING'S ROAD NANYANG PRIMARY SCHOOL SINGAPOR...     52
# 4           0  70 PUNGGOL DRIVE WATERWAY PRIMARY SCHOOL SINGA...     70
#
#                             BUILDING  LATITUDE   LONGITUDE  LONGTITUDE  \
# 0  PRINCESS ELIZABETH PRIMARY SCHOOL  1.349195  103.741000  103.741000
# 1           WOODGROVE PRIMARY SCHOOL  1.433058  103.790390  103.790390
# 2             NANYANG PRIMARY SCHOOL  1.321115  103.806468  103.806468
# 3             NANYANG PRIMARY SCHOOL  1.321246  103.807795  103.807795
# 4            WATERWAY PRIMARY SCHOOL  1.399154  103.918671  103.918671
#
#    POSTAL                  ROAD_NAME                          SEARCHVAL  \
# ...

# %%
schools_gdf.to_file('Generated Files/schools_EPSG3414.shp')

# %%
schools_gdf.plot()
# Out:
# <AxesSubplot:>
